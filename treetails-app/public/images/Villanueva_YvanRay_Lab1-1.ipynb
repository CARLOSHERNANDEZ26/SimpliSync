# %%
# Output 1
## Research & Documentation

Python is the main computer language. It does the hard work that spreadsheets can’t.

- **Cleans Data**: It uses special tools, like **Pandas**, to quickly clean up huge sets of messy sales or customer data.  
- **Finds Answers**: It runs advanced math and builds predictive models to guess future trends, like next month's sales or which customers might leave.  
- **Draws Pictures**: It creates clear charts and graphs, making it easy to see patterns and share what the numbers mean with others.  

---

### Anaconda: The Easy Manager 📦
Anaconda is a simple package that holds Python and all its extra tools.  

- **Simple Start**: Instead of installing dozens of items one by one, you install Anaconda, and it gives you everything you need for data work right away.  
- **Stops Problems**: It keeps different projects neatly separate, so using a tool for one analysis won't break another. It makes sure your work is stable and reliable.  

---

### Jupyter Notebook: The Interactive Report 📓
The Jupyter Notebook is the place where the work is done and written down.  

- **Step-by-Step**: You write small blocks of Python code and run them one at a time. This lets you test and check your work instantly.  
- **Tells the Story**: It puts the code, the pictures (graphs), and your written notes all into one document. This makes the entire analysis clear and easy to follow, like reading a complete report that you can also run yourself.

# %%
#Output 2
# Business Analytics Laboratory – Lab 
**Name:** Villanueva, Yvan Ray 
**Course & BLock:** BSIT 3-D  
**Date:** 10 - 3 - 2025
**Motto:** "If it works, dont touch it. (Dev)"

# %%
#Output 3
# Welcome Message
print("Hello, this is Jc, exploring Business Analytics with Python")

# Arit samples
a, b = 50, 25
print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)

# Loop 
apps = ["Spotify", "Valorant", "Cursor"]
print("My favorite apps are:")
for app in apps:
    print("-", app)

# Dictionary Example
my_info = {"Course": "BSIT", "Block": "3D", "Favorite Tool": "Cursor"}
print(my_info)
# Out:
# Hello, this is Yvan, exploring Business Analytics with Python
# Sum: 75
# Difference: 25
# Product: 1250
# My favorite apps are:
# - Spotify
# - Valorant
# - Cursor
# {'Course': 'BSIT', 'Block': '3D', 'Favorite Tool': 'Cursor'}

# %%
#Output 4
import pandas as pd

# 20 rows of allowance data
csv_data1 = {
    "Date": [f"Sept {i}" for i in range(1, 21)],
    "Allowance": [200]*20,
    "Spent": [150, 180, 170, 160, 190, 175, 165, 185, 170, 160,
              180, 150, 170, 165, 190, 175, 160, 185, 170, 180],
    "Balance": [200 - s for s in 
                [150, 180, 170, 160, 190, 175, 165, 185, 170, 160,
                 180, 150, 170, 165, 190, 175, 160, 185, 170, 180]]
}
df_csv1 = pd.DataFrame(csv_data1)
df_csv1.to_csv("allowance_log.csv", index=False)
pd.read_csv("allowance_log.csv").head()
# Out:
#      Date  Allowance  Spent  Balance
# 0  Sept 1        200    150       50
# 1  Sept 2        200    180       20
# 2  Sept 3        200    170       30
# 3  Sept 4        200    160       40
# 4  Sept 5        200    190       10

# %%
#Output 6
### Reflection
- The most useful tool for me was **Jupyter Notebook because I can mix code and notes  
- The easiest dataset was **CSV** since it was simple. The hardest was excel i dont know what set up i should i use built in or another file  
- next time i'll learn python codes and libraries and syntax of it. i learned this time is the print and some data displaying samples (csv)
