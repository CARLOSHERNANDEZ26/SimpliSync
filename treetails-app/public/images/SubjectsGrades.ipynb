# %%
import pandas as pd

# 20 rows of subjects & grades
csv_data2 = {
    "Subject": [
        "Data Science", "Web Dev", "Business IT", "AI", "Statistics",
        "Networking", "Database", "Operating Systems", "Software Eng", "Cybersecurity",
        "Math Logic", "Linear Algebra", "Discrete Math", "Ethics", "Project Mgmt",
        "UI/UX Design", "Mobile Dev", "Cloud Computing", "IoT", "Big Data"
    ],
    "Grade": [89, 92, 85, 90, 88, 87, 91, 86, 90, 89,
              85, 92, 88, 91, 87, 90, 86, 92, 88, 90]
}

df_csv2 = pd.DataFrame(csv_data2)
df_csv2.to_csv("grades.csv", index=False)
pd.read_csv("grades.csv").head()
# Out:
#         Subject  Grade
# 0  Data Science     89
# 1       Web Dev     92
# 2   Business IT     85
# 3            AI     90
# 4    Statistics     88
